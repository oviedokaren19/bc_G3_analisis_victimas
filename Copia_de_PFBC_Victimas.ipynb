# %% [markdown]
# <a href="https://colab.research.google.com/github/oviedokaren19/bc_G3_analisis_victimas/blob/Karen/Copia_de_PFBC_Victimas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# El data set estaba trucado, se agregó una columna adicional con valores null. Con el siguiente código se eliminó esa columna y se sincronizó con las columnas originales.

# %%
with open('/content/drive/MyDrive/Colab Notebooks/Diciembre_2024.csv', 'r') as f:
    lines = f.readlines()
    lines = [line.rstrip(',\n') + '\n' for line in lines]
with open('/content/archivo_limpio.csv', 'w') as f:
  f.writelines(lines)

# %%
df = pd.read_csv('/content/archivo_limpio.csv')
display(df.head())
# Out:
#                  FECHA_CORTE  \
# 0  31/12/2024 12:00:00 a. m.
# 1  31/12/2024 12:00:00 a. m.
# 2  31/12/2024 12:00:00 a. m.
# 3  31/12/2024 12:00:00 a. m.
# 4  31/12/2024 12:00:00 a. m.
#
#                                              NOM_RPT  COD_PAIS      PAIS  \
# 0  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# 1  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# 2  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# 3  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# 4  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
#
#    COD_ESTADO_DEPTO ESTADO_DEPTO  VIGENCIA  PARAM_HECHO  \
# 0                 0  SIN DEFINIR      1985            1
# 1                 0  SIN DEFINIR      1985            1
# 2                 0  SIN DEFINIR      1985            1
# 3                 0  SIN DEFINIR      1985            1
# 4                 0  SIN DEFINIR      1985            1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529878 entries, 0 to 529877
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   FECHA_CORTE       529878 non-null  object
#  1   NOM_RPT           529878 non-null  object
#  2   COD_PAIS          529878 non-null  int64
#  3   PAIS              529878 non-null  object
#  4   COD_ESTADO_DEPTO  529878 non-null  int64
#  5   ESTADO_DEPTO      529878 non-null  object
#  6   VIGENCIA          529878 non-null  int64
#  7   PARAM_HECHO       529878 non-null  int64
#  8   HECHO             529878 non-null  object
#  9   SEXO              529878 non-null  object
#  10  ETNIA             529878 non-null  object
#  11  DISCAPACIDAD      529878 non-null  object
#  12  CICLO_VITAL       529878 non-null  object
#  13  PER_OCU           529878 non-null  int64
#  14  PER_DECLA         529878 non-null  int64
#  15  EVENTOS           529878 non-null  int64
# ...

# %%
df.describe()
# Out:
#        COD_PAIS  COD_ESTADO_DEPTO       VIGENCIA    PARAM_HECHO  \
# count  529878.0     529878.000000  529878.000000  529878.000000
# mean       48.0         38.084606    2006.707625       5.797253
# std         0.0         30.133328      10.408664       3.752572
# min        48.0          0.000000    1985.000000       1.000000
# 25%        48.0         11.000000    1999.000000       4.000000
# 50%        48.0         27.000000    2007.000000       5.000000
# 75%        48.0         68.000000    2015.000000       6.000000
# max        48.0         99.000000    2024.000000      20.000000
#
#              PER_OCU      PER_DECLA        EVENTOS
# count  529878.000000  529878.000000  529878.000000
# mean       24.517580      24.794728      25.083368
# std       247.703496     237.870861     255.648983
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         1.000000       1.000000       1.000000
# ...

# %%
df.drop('FECHA_CORTE', axis=1, inplace=True) #Se elimina la columna FECHA_CORTE ya que no aporta ninguna información relevante para el análisis y se indexó con un valor autonumerado.
df
# Out:
#                                                   NOM_RPT  COD_PAIS      PAIS  \
# 0       REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# 1       REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# 2       REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# 3       REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# 4       REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# ...                                                   ...       ...       ...
# 529873  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# 529874  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# 529875  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# 529876  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
# 529877  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...        48  COLOMBIA
#
# ...
