# %% [markdown]
# <a href="https://colab.research.google.com/github/oviedokaren19/bc_G3_analisis_victimas/blob/main/PFBC_Victimas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Presentación

# %% [markdown]
# Es el primer cambio !!!!

# %% [markdown]
# # Justificación

# %%
#¿cúal es la afectación a comunidades indigenas por el conflicto armado? ¿cúal es el departamento con mayor ocurrecia de hechos victimizantes?

# %% [markdown]
# # Ingestión de Datos

# %% [markdown]
# # Preparación y Limpieza

# %% [markdown]
# # Analítica descriptiva

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Diciembre_2024.csv')
df
# Out:
#                                                                  FECHA_CORTE  \
# 31/12/2024 12:00:00 a. m.  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...
# 31/12/2024 12:00:00 a. m.  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...
# 31/12/2024 12:00:00 a. m.  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...
# 31/12/2024 12:00:00 a. m.  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...
# 31/12/2024 12:00:00 a. m.  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...
# ...                                                                      ...
# 31/12/2024 12:00:00 a. m.  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...
# 31/12/2024 12:00:00 a. m.  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...
# 31/12/2024 12:00:00 a. m.  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...
# 31/12/2024 12:00:00 a. m.  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...
# 31/12/2024 12:00:00 a. m.  REPORTE VICTIMAS ANUALIZADO POR HECHO, CIFRA D...
#
#                            NOM_RPT  COD_PAIS  PAIS COD_ESTADO_DEPTO  \
# 31/12/2024 12:00:00 a. m.       48  COLOMBIA     0      SIN DEFINIR
# 31/12/2024 12:00:00 a. m.       48  COLOMBIA     0      SIN DEFINIR
# 31/12/2024 12:00:00 a. m.       48  COLOMBIA     0      SIN DEFINIR
# 31/12/2024 12:00:00 a. m.       48  COLOMBIA     0      SIN DEFINIR
# 31/12/2024 12:00:00 a. m.       48  COLOMBIA     0      SIN DEFINIR
# ...                            ...       ...   ...              ...
# 31/12/2024 12:00:00 a. m.       48  COLOMBIA    99          Vichada
# 31/12/2024 12:00:00 a. m.       48  COLOMBIA    99          Vichada
# 31/12/2024 12:00:00 a. m.       48  COLOMBIA    99          Vichada
# 31/12/2024 12:00:00 a. m.       48  COLOMBIA    99          Vichada
# 31/12/2024 12:00:00 a. m.       48  COLOMBIA    99          Vichada
#
#                            ESTADO_DEPTO  VIGENCIA  \
# 31/12/2024 12:00:00 a. m.          1985         1
# 31/12/2024 12:00:00 a. m.          1985         1
# 31/12/2024 12:00:00 a. m.          1985         1
# 31/12/2024 12:00:00 a. m.          1985         1
# 31/12/2024 12:00:00 a. m.          1985         1
# ...                                 ...       ...
# 31/12/2024 12:00:00 a. m.          2024        12
# 31/12/2024 12:00:00 a. m.          2024        12
# 31/12/2024 12:00:00 a. m.          2024        15
# 31/12/2024 12:00:00 a. m.          2024        15
# 31/12/2024 12:00:00 a. m.          2024        15
#
#                                                                  PARAM_HECHO  \
# 31/12/2024 12:00:00 a. m.  Acto terrorista / Atentados / Combates / Enfre...
# 31/12/2024 12:00:00 a. m.  Acto terrorista / Atentados / Combates / Enfre...
# 31/12/2024 12:00:00 a. m.  Acto terrorista / Atentados / Combates / Enfre...
# 31/12/2024 12:00:00 a. m.  Acto terrorista / Atentados / Combates / Enfre...
# 31/12/2024 12:00:00 a. m.  Acto terrorista / Atentados / Combates / Enfre...
# ...                                                                      ...
# 31/12/2024 12:00:00 a. m.              Perdida de Bienes Muebles o Inmuebles
# 31/12/2024 12:00:00 a. m.              Perdida de Bienes Muebles o Inmuebles
# 31/12/2024 12:00:00 a. m.                                      Confinamiento
# 31/12/2024 12:00:00 a. m.                                      Confinamiento
# 31/12/2024 12:00:00 a. m.                                      Confinamiento
#
#                             HECHO                      SEXO    ETNIA  \
# 31/12/2024 12:00:00 a. m.  Hombre  Indigena (Acreditado RA)   Fisica
# 31/12/2024 12:00:00 a. m.  Hombre  Indigena (Acreditado RA)  Ninguna
# 31/12/2024 12:00:00 a. m.  Hombre  Indigena (Acreditado RA)  Ninguna
# 31/12/2024 12:00:00 a. m.  Hombre  Indigena (Acreditado RA)  Ninguna
# 31/12/2024 12:00:00 a. m.  Hombre  Indigena (Acreditado RA)  Ninguna
# ...                           ...                       ...      ...
# 31/12/2024 12:00:00 a. m.   Mujer  Indigena (Acreditado RA)  Ninguna
# 31/12/2024 12:00:00 a. m.   Mujer                   Ninguna  Ninguna
# 31/12/2024 12:00:00 a. m.  Hombre                   Ninguna  Ninguna
# 31/12/2024 12:00:00 a. m.  Hombre                   Ninguna  Ninguna
# 31/12/2024 12:00:00 a. m.   Mujer                   Ninguna  Ninguna
#
#                              DISCAPACIDAD  CICLO_VITAL  PER_OCU  PER_DECLA  \
# 31/12/2024 12:00:00 a. m.  entre 60 y 110            0        0          0
# 31/12/2024 12:00:00 a. m.   entre 12 y 17            0        0          0
# 31/12/2024 12:00:00 a. m.   entre 18 y 28            0        0          0
# 31/12/2024 12:00:00 a. m.   entre 29 y 59            0        0          0
# 31/12/2024 12:00:00 a. m.  entre 60 y 110            0        0          0
# ...                                   ...          ...      ...        ...
# 31/12/2024 12:00:00 a. m.   entre 29 y 59            1        0          1
# 31/12/2024 12:00:00 a. m.   entre 29 y 59            1        0          1
# 31/12/2024 12:00:00 a. m.   entre 18 y 28            0        0          0
# 31/12/2024 12:00:00 a. m.   entre 29 y 59            0        0          0
# 31/12/2024 12:00:00 a. m.   entre 18 y 28            0        0          0
#
#                            EVENTOS
# 31/12/2024 12:00:00 a. m.      NaN
# 31/12/2024 12:00:00 a. m.      NaN
# 31/12/2024 12:00:00 a. m.      NaN
# 31/12/2024 12:00:00 a. m.      NaN
# 31/12/2024 12:00:00 a. m.      NaN
# ...                            ...
# 31/12/2024 12:00:00 a. m.      NaN
# 31/12/2024 12:00:00 a. m.      NaN
# 31/12/2024 12:00:00 a. m.      NaN
# 31/12/2024 12:00:00 a. m.      NaN
# 31/12/2024 12:00:00 a. m.      NaN
#
# [529878 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# FECHA_CORTE     0
# NOM_RPT         0
# SEXO            0
# ETNIA           0
# DISCAPACIDAD    0
# CICLO_VITAL     0
# PER_OCU         0
# PER_SA          0
# EVENTOS         0
# dtype: int64
