# %% [markdown]
# <a href="https://colab.research.google.com/github/oviedokaren19/bc_G3_analisis_victimas/blob/main/PFBC_Victimas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Presentación

# %% [markdown]
# Hola Empezamos Proyecto Final Vamos con toda!!

# %% [markdown]
# # Justificación

# %% [markdown]
# # Ingestión de Datos

# %% [markdown]
# # Preparación y Limpieza

# %% [markdown]
# # Analítica descriptiva

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Datos_unificados_UARIV.csv')
df
# Out:
#                      FECHA_CORTE  \
# 0      31/01/2024 12:00:00 a. m.
# 1      31/01/2024 12:00:00 a. m.
# 2      31/01/2024 12:00:00 a. m.
# 3      31/01/2024 12:00:00 a. m.
# 4      31/01/2024 12:00:00 a. m.
# ...                          ...
# 14919  31/05/2025 12:00:00 a. m.
# 14920  31/05/2025 12:00:00 a. m.
# 14921  31/05/2025 12:00:00 a. m.
# 14922  31/05/2025 12:00:00 a. m.
# 14923  31/05/2025 12:00:00 a. m.
#
#                                                  NOM_RPT        SEXO  \
# 0      REPORTE VICTIMAS, CIFRA NACIONAL (SEXO, ETNIA,...      Hombre
# 1      REPORTE VICTIMAS, CIFRA NACIONAL (SEXO, ETNIA,...      Hombre
# 2      REPORTE VICTIMAS, CIFRA NACIONAL (SEXO, ETNIA,...      Hombre
# 3      REPORTE VICTIMAS, CIFRA NACIONAL (SEXO, ETNIA,...      Hombre
# 4      REPORTE VICTIMAS, CIFRA NACIONAL (SEXO, ETNIA,...      Hombre
# ...                                                  ...         ...
# 14919  REPORTE VICTIMAS, CIFRA NACIONAL (SEXO, ETNIA,...  No Informa
# 14920  REPORTE VICTIMAS, CIFRA NACIONAL (SEXO, ETNIA,...  No Informa
# 14921  REPORTE VICTIMAS, CIFRA NACIONAL (SEXO, ETNIA,...  No Informa
# 14922  REPORTE VICTIMAS, CIFRA NACIONAL (SEXO, ETNIA,...  No Informa
# 14923  REPORTE VICTIMAS, CIFRA NACIONAL (SEXO, ETNIA,...  No Informa
#
#                                                    ETNIA DISCAPACIDAD  \
# 0                         Afrocolombiano (Acreditado RA)      Ninguna
# 1                         Afrocolombiano (Acreditado RA)      Ninguna
# 2                         Afrocolombiano (Acreditado RA)      Ninguna
# 3                         Afrocolombiano (Acreditado RA)      Ninguna
# 4                          Gitano (RROM) (Acreditado RA)     Auditiva
# ...                                                  ...          ...
# 14919                                            Ninguna      Ninguna
# 14920                                            Ninguna      Ninguna
# 14921                                            Ninguna       Visual
# 14922  Raizal del Archipielago de San Andres y Provid...      Ninguna
# 14923  Raizal del Archipielago de San Andres y Provid...      Ninguna
#
#           CICLO_VITAL  PER_OCU  PER_SA  EVENTOS
# 0        entre 6 y 11        8       8       11
# 1       entre 12 y 17       10       9       16
# 2       entre 18 y 28       19      19       30
# 3       entre 29 y 60       21      17       27
# 4      entre 61 y 100        1       0        1
# ...               ...      ...     ...      ...
# 14919              ND      107      71      117
# 14920   entre 29 y 59       89      75       95
# 14921   entre 29 y 59        1       0        1
# 14922  entre 60 y 110        2       2        2
# 14923   entre 29 y 59        2       2        2
#
# [14924 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# FECHA_CORTE     0
# NOM_RPT         0
# SEXO            0
# ETNIA           0
# DISCAPACIDAD    0
# CICLO_VITAL     0
# PER_OCU         0
# PER_SA          0
# EVENTOS         0
# dtype: int64
